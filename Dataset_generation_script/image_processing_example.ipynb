# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from filter_images import get_kernel, object_convolution

# %matplotlib inline

# %%
img = cv2.imread("./ADE20K_2021_17_01/images/ADE/training/urban/forest_road/ADE_frame_00000153.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off');

# %%
psfs = get_kernel(canvas=33)
kernel = psfs[2] * 2
for i in range(9):
    mask = cv2.imread(f"./ADE20K_2021_17_01/images/ADE/training/urban/forest_road/ADE_frame_00000153/instance_00{i}_ADE_frame_00000153.png")
    cv2.normalize(kernel, kernel, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
    img = object_convolution(img, kernel, mask)
    
psfs = get_kernel(canvas=33)
kernel = psfs[2] * 2
mask = cv2.imread("./ADE20K_2021_17_01/images/ADE/training/urban/forest_road/ADE_frame_00000153/instance_009_ADE_frame_00000153.png")
cv2.normalize(kernel, kernel, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
img = object_convolution(img, kernel, mask)
mask = cv2.imread("./ADE20K_2021_17_01/images/ADE/training/urban/forest_road/ADE_frame_00000153/instance_010_ADE_frame_00000153.png")
img = object_convolution(img, kernel, mask)

plt.imshow(img)
plt.axis('off')
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
cv2.imwrite("blured.png", img)
# Out:
# True
